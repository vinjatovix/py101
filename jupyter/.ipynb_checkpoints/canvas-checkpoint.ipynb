# %%
import pandas as pd

# %%
import webbrowser
website = 'https://es.wikipedia.org/wiki/Conjunto_de_Mandelbrot'
webbrowser.open(website)
# Out:
# True

# %%
dataframe_extremo = pd.read_clipboard()

# %%
dataframe_extremo
# Out:
#              Año     Álbumes              de     estudio  Posición       en  \
# 0        Bandera          de          España        None      None     None
# 1            24​        None            None        None      None     None
# 2           1989        Rock  transgresivon.          1​      None     None
# 3         Sello:      Avispa            None        None      None     None
# 4   Publicación:          26              de      agosto        de     1994
# 5              —        None            None        None      None     None
# 6           ESP:      Oro26​            None        None      None     None
# 7           1991       Somos            unos    animales      None     None
# 8         Sello:        Área        Creativa        None      None     None
# 9   Publicación:       Julio              de     199127​      None     None
# 10             —        None            None        None      None     None
# ...

# %%
dataframe_extremo.columns
# Out:
# Index(['Año', 'Álbumes', 'de', 'estudio', 'Posición', 'en', 'listas',
#        'Certificaciones'],
#       dtype='object')

# %%
dataframe_extremo['Año']
# Out:
# 0          Bandera
# 1              24​
# 2             1989
# 3           Sello:
# 4     Publicación:
# 5                —
# 6             ESP:
# 7             1991
# 8           Sello:
# 9     Publicación:
# 10               —
# 11            ESP:
# 12            1992
# 13          Sello:
# 14    Publicación:
# 15               —
# 16            ESP:
# 17            1993
# 18          Sello:
# 19    Publicación:
# 20               —
# 21            ESP:
# 22            1995
# 23          Sello:
# 24    Publicación:
# 25               —
# 26            ESP:
# 27            1996
# 28          Sello:
# 29    Publicación:
# 30           1336​
# 31            ESP:
# 32            1998
# 33          Sello:
# 34    Publicación:
# 35            438​
# 36            ESP:
# 37            2002
# 38          Sello:
# 39    Publicación:
# 40            442​
# 41            ESP:
# 42            2008
# 43          Sello:
# 44    Publicación:
# 45               1
# 46            ESP:
# ...

# %%
dataframe_extremo.head(3)
# Out:
#        Año Álbumes              de estudio Posición    en listas  \
# 0  Bandera      de          España    None     None  None   None
# 1      24​    None            None    None     None  None   None
# 2     1989    Rock  transgresivon.      1​     None  None   None
#
#   Certificaciones
# 0            None
# 1            None
# 2            None

# %%
dataframe_extremo.tail(3)
# Out:
#              Año     Álbumes    de    estudio Posición       en listas  \
# 54  Publicación:           8    de  noviembre       de  201346​   None
# 55             1        None  None       None     None     None   None
# 56          ESP:  Platino47​  None       None     None     None   None
#
#    Certificaciones
# 54            None
# 55            None
# 56            None

# %%
lista = ['mates','historia','fisica']
notas = [7,8,9]
dic = {'Asignaturas':lista, 'notas':notas}

# %%
dic
# Out:
# {'Asignaturas': ['mates', 'historia', 'fisica'], 'notas': [7, 8, 9]}

# %%
dfnotas = pd.DataFrame(dic)

# %%
dfnotas
# Out:
#   Asignaturas  notas
# 0       mates      7
# 1    historia      8
# 2      fisica      9

# %%
### indices

# %%
l_valores = [1,2,3]
l_indices = ['a','b','c']
serie = pd.Series(l_valores, index=l_indices)
serie.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
serie.index[0] # se pueden cambiar los valores pero no lo indices
# Out:
# 'a'

# %%
lista_valores = [[1,2,3],[2,5,8],[5,8,3]]
lista_indices = ['mates','historia','fisica']
lista_nombres = ['pablo','pedro','pepe']

df = pd.DataFrame(lista_valores, index=lista_indices,columns=lista_nombres)

# %%
df
# Out:
#           pablo  pedro  pepe
# mates         1      2     3
# historia      2      5     8
# fisica        5      8     3

# %%
df.index
# Out:
# Index(['mates', 'historia', 'fisica'], dtype='object')

# %%
df.index[2]
# Out:
# 'fisica'

# %%
# Eliminar elementos en series y dataframes

# %%
import pandas as pd
import numpy as np

# %%
np.arange(3)
# Out:
# array([0, 1, 2])

# %%
serie = pd.Series(np.arange(4), index=['a','b','c','d'])

# %%
serie
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int32

# %%
serie.drop('c')
# Out:
# a    0
# b    1
# d    3
# dtype: int32

# %%
lv = np.arange(9).reshape(3,3)

# %%
li = ['a','b','c']
lc = ['c1','c2','c3']

df = pd.DataFrame(lv, index=li, columns=lc)
df
# Out:
#    c1  c2  c3
# a   0   1   2
# b   3   4   5
# c   6   7   8

# %%
df.drop('b')
# Out:
#    c1  c2  c3
# a   0   1   2
# c   6   7   8

# %%
df.drop('c3',axis=1)
# Out:
#    c1  c2
# a   0   1
# b   3   4
# c   6   7

# %%
# seleccionando datos en las series

# %%
import pandas as pd
import numpy as np

# %%
lv = np.arange(3)
li = ['i1','i2','i3']

li
# Out:
# ['i1', 'i2', 'i3']

# %%
serie = pd.Series(lv, index=li)

# %%
serie
# Out:
# i1    0
# i2    1
# i3    2
# dtype: int32

# %%
serie = serie *2

# %%
serie
# Out:
# i1    0
# i2    2
# i3    4
# dtype: int32

# %%
serie['i2']*4
# Out:
# 8
